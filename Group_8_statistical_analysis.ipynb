# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data.txt")

# %%
df.head()
# Out:
#    ID  Age  Gender  Income     City  Score
# 0   1   26  Female   84268   Kisumu     61
# 1   2   39  Female   48141  Eldoret     91
# 2   3   48  Female   86044  Nairobi     82
# 3   4   34  Female   97214  Eldoret     81
# 4   5   30    Male   63827   Kisumu     84

# %%
df.tail()
# Out:
#      ID  Age  Gender  Income     City  Score
# 95   96   48    Male   73016  Nairobi     60
# 96   97   37  Female   37400  Eldoret     92
# 97   98   45    Male   72642   Kisumu     99
# 98   99   31    Male   45151  Eldoret     69
# 99  100   21  Female   81407  Mombasa     88

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      100 non-null    int64
#  1   Age     100 non-null    int64
#  2   Gender  100 non-null    object
#  3   Income  100 non-null    int64
#  4   City    100 non-null    object
#  5   Score   100 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#                ID         Age        Income       Score
# count  100.000000  100.000000    100.000000  100.000000
# mean    50.500000   35.630000  66562.360000   80.380000
# std     29.011492    9.033781  20672.986588   11.959342
# min      1.000000   20.000000  30854.000000   60.000000
# 25%     25.750000   27.000000  50234.250000   71.000000
# 50%     50.500000   37.000000  68063.500000   82.000000
# 75%     75.250000   44.000000  84297.000000   91.000000
# max    100.000000   49.000000  99163.000000   99.000000

# %%
df.shape
# Out:
# (100, 6)

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Income', 'City', 'Score'], dtype='object')

# %%
df['Income'].mean()
print(f'mean income is {df["Income"].mean()}')
df['Score'].mean()
print(f'mean score is {df["Score"].mean()}')
df['Age'].mean()
print(f'mean age is {df["Age"].mean()}')
# Out:
# mean income is 66562.36
# mean score is 80.38
# mean age is 35.63

# %%
df['Income'].median()
print(f'median income is {df["Income"].median()}')
df['Score'].median()
print(f'median score is {df["Score"].median()}')
df['Age'].mean()
print(f'median age is {df["Age"].median()}')
# Out:
# median income is 68063.5
# median score is 82.0
# median age is 37.0

# %%
age = df['Age']
age
# Out:
# 0     26
# 1     39
# 2     48
# 3     34
# 4     30
#       ..
# 95    48
# 96    37
# 97    45
# 98    31
# 99    21
# Name: Age, Length: 100, dtype: int64

# %%
score = df['Score']

# %%
import matplotlib.pyplot as plt

# %%
#plotting a histogram
bins = 6
plt.hist(age, bins, edgecolor="black", color="springgreen")
plt.title("The Age Plot!")
plt.xlabel("Age")
plt.ylabel("Score")
plt.show()

# %%
score_10 = score[:10]
score_10
# Out:
# 0    61
# 1    91
# 2    82
# 3    81
# 4    84
# 5    81
# 6    81
# 7    65
# 8    74
# 9    96
# Name: Score, dtype: int64

# %%
age = df['Age']
age
# Out:
# 0     26
# 1     39
# 2     48
# 3     34
# 4     30
#       ..
# 95    48
# 96    37
# 97    45
# 98    31
# 99    21
# Name: Age, Length: 100, dtype: int64

# %%
age_10 = age[:10]
age_10
# Out:
# 0    26
# 1    39
# 2    48
# 3    34
# 4    30
# 5    27
# 6    48
# 7    40
# 8    26
# 9    45
# Name: Age, dtype: int64

# %%
# plotting a linegragh
Score = score_10

plt.plot(score_10, marker='o', linestyle='-', color='green')
plt.title("Score Plot")
plt.xlabel("Index")
plt.ylabel("Score")
plt.show()

# %%
# Boxplot
age = age_10
plt.boxplot(age, )#showfliers=False)
plt.title("Age Plot")
plt.show()

# %%
# Plot a Bar chart
plt.bar(age_10, score_10, color='indigo')
plt.title("Score Plot")
plt.xlabel("Age")
plt.ylabel("Score")
plt.show()

# %%
#iloc

# %%
df.iloc[4]
# Out:
# ID             5
# Age           30
# Gender      Male
# Income     63827
# City      Kisumu
# Score         84
# Name: 4, dtype: object

# %%
df.iloc[2:5]
# Out:
#    ID  Age  Gender  Income     City  Score
# 2   3   48  Female   86044  Nairobi     82
# 3   4   34  Female   97214  Eldoret     81
# 4   5   30    Male   63827   Kisumu     84

# %%
df.iloc[:, 3:5]
# Out:
#     Income     City
# 0    84268   Kisumu
# 1    48141  Eldoret
# 2    86044  Nairobi
# 3    97214  Eldoret
# 4    63827   Kisumu
# ..     ...      ...
# 95   73016  Nairobi
# 96   37400  Eldoret
# 97   72642   Kisumu
# 98   45151  Eldoret
# 99   81407  Mombasa
#
# [100 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'Income', 'City', 'Score'], dtype='object')

# %%
df.iloc[2:4, 2:4]
# Out:
#    Gender  Income
# 2  Female   86044
# 3  Female   97214

# %%
df.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
df.loc[2:10, 'Income']
# Out:
# 2     86044
# 3     97214
# 4     63827
# 5     85820
# 6     92623
# 7     52299
# 8     73585
# 9     94044
# 10    72557
# Name: Income, dtype: int64

# %%
df.loc[2:10, 'Income':'Score']
# Out:
#     Income     City  Score
# 2    86044  Nairobi     82
# 3    97214  Eldoret     81
# 4    63827   Kisumu     84
# 5    85820  Nairobi     81
# 6    92623  Eldoret     81
# 7    52299  Eldoret     65
# 8    73585   Kisumu     74
# 9    94044  Nairobi     96
# 10   72557   Kisumu     92

# %%
df.loc[:, 'Score']
# Out:
# 0     61
# 1     91
# 2     82
# 3     81
# 4     84
#       ..
# 95    60
# 96    92
# 97    99
# 98    69
# 99    88
# Name: Score, Length: 100, dtype: int64

# %%
df.loc[df['Score']>80]
# Out:
#      ID  Age  Gender  Income     City  Score
# 1     2   39  Female   48141  Eldoret     91
# 2     3   48  Female   86044  Nairobi     82
# 3     4   34  Female   97214  Eldoret     81
# 4     5   30    Male   63827   Kisumu     84
# 5     6   27  Female   85820  Nairobi     81
# 6     7   48    Male   92623  Eldoret     81
# 9    10   45    Male   94044  Nairobi     96
# 10   11   38  Female   72557   Kisumu     92
# 13   14   30  Female   99163  Mombasa     98
# 16   17   23    Male   72941   Kisumu     91
# 17   18   27  Female   51834   Nakuru     89
# 18   19   43    Male   48047  Nairobi     94
# 19   20   22    Male   56105  Eldoret     99
# 22   23   21    Male   74262  Nairobi     89
# 26   27   25    Male   91373  Nairobi     87
# 27   28   21    Male   36776  Nairobi     85
# 28   29   47    Male   85016  Eldoret     96
# 29   30   40    Male   39474   Kisumu     85
# 30   31   20    Male   88053   Kisumu     82
# 35   36   31  Female   96199  Mombasa     93
# ...

# %%
df.loc[df['Score']<=80, 'Income']
# Out:
# 0     84268
# 7     52299
# 8     73585
# 11    79080
# 12    32693
# 14    55939
# 15    78925
# 20    45707
# 21    51976
# 23    53776
# 24    60080
# 25    96842
# 31    51959
# 32    35530
# 33    33748
# 34    43545
# 39    84384
# 40    81005
# 42    69353
# 45    95318
# 46    53664
# 48    56736
# 52    85680
# 54    80859
# 56    93734
# 57    82662
# 58    42688
# 61    97863
# 68    81663
# 69    45708
# 73    64754
# 74    41411
# 76    97270
# 77    38680
# 78    41111
# 79    67504
# 81    38155
# 82    69384
# 86    60306
# 88    76843
# 93    59855
# 94    91434
# 95    73016
# 98    45151
# Name: Income, dtype: int64

# %%
df.loc[df['Score']<=80, ['Income', 'Score', 'Age']]
# Out:
#     Income  Score  Age
# 0    84268     61   26
# 7    52299     65   40
# 8    73585     74   26
# 11   79080     67   42
# 12   32693     64   30
# 14   55939     63   43
# 15   78925     65   40
# 20   45707     75   41
# 21   51976     72   40
# 23   53776     78   43
# 24   60080     76   31
# 25   96842     78   49
# 31   51959     68   31
# 32   35530     71   45
# 33   33748     60   41
# 34   43545     60   48
# 39   84384     60   46
# 40   81005     75   29
# 42   69353     64   47
# 45   95318     62   49
# 46   53664     71   49
# 48   56736     75   49
# 52   85680     73   39
# 54   80859     64   22
# 56   93734     64   38
# 57   82662     71   26
# 58   42688     75   40
# 61   97863     80   37
# 68   81663     69   28
# 69   45708     64   45
# 73   64754     69   47
# 74   41411     78   34
# 76   97270     60   26
# 77   38680     64   31
# 78   41111     63   48
# 79   67504     75   27
# 81   38155     75   22
# 82   69384     61   33
# 86   60306     79   27
# ...

# %%
#series selectors

# %%
sr_score = df['Score']
#type(sr_score)
sr_score
# Out:
# 0     61
# 1     91
# 2     82
# 3     81
# 4     84
#       ..
# 95    60
# 96    92
# 97    99
# 98    69
# 99    88
# Name: Score, Length: 100, dtype: int64

# %%
sr_score[0:10]
# Out:
# 0    61
# 1    91
# 2    82
# 3    81
# 4    84
# 5    81
# 6    81
# 7    65
# 8    74
# 9    96
# Name: Score, dtype: int64

# %%
sr_score[sr_score>80]
# Out:
# 1     91
# 2     82
# 3     81
# 4     84
# 5     81
# 6     81
# 9     96
# 10    92
# 13    98
# 16    91
# 17    89
# 18    94
# 19    99
# 22    89
# 26    87
# 27    85
# 28    96
# 29    85
# 30    82
# 35    93
# 36    91
# 37    84
# 38    99
# 41    98
# 43    81
# 44    88
# 47    85
# 49    96
# 50    81
# 51    88
# 53    87
# 55    89
# 59    85
# 60    85
# 62    98
# 63    95
# 64    92
# 65    89
# 66    96
# 67    82
# 70    95
# 71    93
# 72    90
# 75    91
# 80    83
# 83    87
# 84    91
# 85    86
# 87    83
# 89    94
# 90    92
# 91    92
# 92    96
# 96    92
# 97    99
# 99    88
# Name: Score, dtype: int64

# %%
df.loc[df['Income']<60000, ['Income']] = 70000
df.loc[0:50, 'Income']
# Out:
# 0     84268
# 1     70000
# 2     86044
# 3     97214
# 4     63827
# 5     85820
# 6     92623
# 7     70000
# 8     73585
# 9     94044
# 10    72557
# 11    79080
# 12    70000
# 13    99163
# 14    70000
# 15    78925
# 16    72941
# 17    70000
# 18    70000
# 19    70000
# 20    70000
# 21    70000
# 22    74262
# 23    70000
# 24    60080
# 25    96842
# 26    91373
# 27    70000
# 28    85016
# 29    70000
# 30    88053
# 31    70000
# 32    70000
# 33    70000
# 34    70000
# 35    96199
# 36    64766
# 37    91087
# 38    98840
# 39    84384
# 40    81005
# 41    76576
# 42    69353
# 43    92003
# 44    82733
# 45    95318
# 46    70000
# 47    97172
# 48    70000
# 49    70000
# 50    68623
# Name: Income, dtype: int64
